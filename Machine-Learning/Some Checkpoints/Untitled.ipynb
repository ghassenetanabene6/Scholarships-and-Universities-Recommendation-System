# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %%
# Générer des données:
X, y = make_blobs(n_samples=1000, centers = 5, cluster_std=1.5, random_state=40) #nb_feat
plt.scatter(X[:,0], X[:, 1])

# %%
print(X.shape)
# Out:
# (1000, 2)

# %%
# Entrainer le modele de K-mean Clustering
model = KMeans(n_clusters=5)
model.fit(X)

#Visualiser les Clusters
predictions = model.predict(X)
plt.scatter(X[:,0], X[:,1], c=predictions)

# %%
#print(predictions)
#print(X[0])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, predictions, random_state=40, train_size=0.7)

# %%
plt.scatter(x_train[:,0], x_train[:,1], c=y_train)

# %%
plt.scatter(x_test[:,0], x_test[:,1], c=y_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn import neighbors
result = []
n_values = range(1,20)
for n in n_values:
    clf = neighbors.KNeighborsClassifier(n_neighbors=n)
    clf.fit(x_train, y_train)
    Z = clf.predict(x_test)
    score = accuracy_score(Z, y_test)
    result.append(score)

plt.plot(list(n_values), result)

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors=6)
clf.fit(x_train, y_train)
a = clf.predict(x_test)
plt.scatter(x_test[:,0], x_test[:,1], c=a)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer() #max_df=0.95, min_df=2, stop_words='english'

# %%
dtm = tfidf.fit_transform(['This is the first document.','This document is the second document.','And this is the third one.','Is this the first document?',])

# %%
dtm = tfidf.fit_transform(['This is the first document.',])

# %%
print(tfidf.vocabulary_)
print(tfidf.idf_)
print(dtm.shape)
print(dtm.toarray())
# Out:
# {'this': 8, 'is': 3, 'the': 6, 'first': 2, 'document': 1, 'second': 5, 'and': 0, 'third': 7, 'one': 4}
# [1.91629073 1.22314355 1.51082562 1.         1.91629073 1.91629073
#  1.         1.91629073 1.        ]
# (4, 9)
# [[0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]
#  [0.         0.6876236  0.         0.28108867 0.         0.53864762
#   0.28108867 0.         0.28108867]
#  [0.51184851 0.         0.         0.26710379 0.51184851 0.
#   0.26710379 0.51184851 0.26710379]
#  [0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]]

# %%
model = KMeans(n_clusters=4)
f=np.random.random((2000,3))
model.fit(f)

predictions = model.predict(f)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(f[:,0],f[:,1],f[:,2], c=predictions)
plt.show()
